# %% [markdown]
# ## Load Dataset

# %%
import numpy as np
import pandas as pd

import zipfile
import os

# %%
# extract zip file to dataset dir
def unzip_file(zip_file, extract_dir):
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

zip_file = 'healthcare-provider-fraud-detection-analysis.zip'
extract_dir = 'dataset'

unzip_file(zip_file, extract_dir)

# %%
for dirname, _, filenames in os.walk('dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# dataset/Train-1542865627584.csv
# dataset/Test_Beneficiarydata-1542969243754.csv
# dataset/Train_Beneficiarydata-1542865627584.csv
# dataset/Test_Outpatientdata-1542969243754.csv
# dataset/Test-1542969243754.csv
# dataset/Train_Outpatientdata-1542865627584.csv
# dataset/Train_Inpatientdata-1542865627584.csv
# dataset/Test_Inpatientdata-1542969243754.csv

# %%
import pandas as pd
pd.set_option('display.max_columns',100)

df_test_ben = pd.read_csv('dataset/Test_Beneficiarydata-1542969243754.csv')
df_test_inp = pd.read_csv('dataset/Test_Inpatientdata-1542969243754.csv')
df_test_out = pd.read_csv('dataset/Test_Outpatientdata-1542969243754.csv')

# %%
print(f'Shape of data: {df_test_ben.shape[0]} row and {df_test_ben.shape[1]} columns')
df_test_ben.head()
# Out:
# Shape of data: 63968 row and 25 columns
#       BeneID         DOB         DOD  Gender  Race RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01         NaN       1     1                     0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                     0
# 2  BENE11010  1936-07-01         NaN       2     1                     0
# 3  BENE11011  1914-03-01         NaN       2     2                     0
# 4  BENE11014  1938-04-01         NaN       2     1                     Y
#
#    State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# 0     39     230                   12                   12
# 1     45     610                   12                   12
# 2     41      30                   12                   12
# 3      1     360                   12                   12
# 4     45     780                   12                   12
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# ...

# %%
print(f'Shape of data: {df_test_inp.shape[0]} row and {df_test_inp.shape[1]} columns')
df_test_inp.head()
# Out:
# Shape of data: 9551 row and 30 columns
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-09-09                  5789             1068.0
# ...

# %%
print(f'Shape of data: {df_test_out.shape[0]} row and {df_test_out.shape[1]} columns')
df_test_out.head()
# Out:
# Shape of data: 125841 row and 27 columns
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0      PHY347633              V5832              V5861               2724
# ...

# %%
df_test_out.Provider.nunique()
# Out:
# 1259
