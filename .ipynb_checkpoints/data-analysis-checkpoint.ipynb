# %% [markdown]
# ## Load Dataset

# %%
import numpy as np
import pandas as pd

import zipfile
import os

# %%
pd.set_option('display.max_columns',100)

# %%
# extract zip file to dataset dir
def unzip_file(zip_file, extract_dir):
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

zip_file = 'healthcare-provider-fraud-detection-analysis.zip'
extract_dir = 'dataset'

unzip_file(zip_file, extract_dir)

# %%
for dirname, _, filenames in os.walk('dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# dataset/Train-1542865627584.csv
# dataset/Test_Beneficiarydata-1542969243754.csv
# dataset/Train_Beneficiarydata-1542865627584.csv
# dataset/Test_Outpatientdata-1542969243754.csv
# dataset/Test-1542969243754.csv
# dataset/Train_Outpatientdata-1542865627584.csv
# dataset/Train_Inpatientdata-1542865627584.csv
# dataset/Test_Inpatientdata-1542969243754.csv
# dataset/.ipynb_checkpoints/Test-1542969243754-checkpoint.csv
# dataset/.ipynb_checkpoints/Train_Inpatientdata-1542865627584-checkpoint.csv
# dataset/.ipynb_checkpoints/Train_Outpatientdata-1542865627584-checkpoint.csv
# dataset/.ipynb_checkpoints/Train-1542865627584-checkpoint.csv

# %%
df_train = pd.read_csv('dataset/Train-1542865627584.csv')
df_train_be = pd.read_csv('dataset/Train_Beneficiarydata-1542865627584.csv')
df_train_ip = pd.read_csv('dataset/Train_Inpatientdata-1542865627584.csv')
df_train_op = pd.read_csv('dataset/Train_Outpatientdata-1542865627584.csv')

# %%
df_test = pd.read_csv('dataset/Test-1542969243754.csv')
df_test_be = pd.read_csv('dataset/Test_Beneficiarydata-1542969243754.csv')
df_test_ip = pd.read_csv('dataset/Test_Inpatientdata-1542969243754.csv')
df_test_op = pd.read_csv('dataset/Test_Outpatientdata-1542969243754.csv')

# %% [markdown]
# ## Data Profilling

# %%
df_train_op.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# 1            NaN               6115                NaN                NaN
# 2            NaN               2723                NaN                NaN
# 3            NaN              71988                NaN                NaN
# 4            NaN              82382              30000              72887
#
#   ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6 ClmDiagnosisCode_7  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4               4280               7197              V4577                NaN
#
#   ClmDiagnosisCode_8 ClmDiagnosisCode_9 ClmDiagnosisCode_10  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                NaN                NaN                 NaN
# 3                NaN                NaN                 NaN
# 4                NaN                NaN                 NaN
#
#    ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    DeductibleAmtPaid ClmAdmitDiagnosisCode
# 0                  0                 56409
# 1                  0                 79380
# 2                  0                   NaN
# 3                  0                   NaN
# 4                  0                 71947

# %%
Train_Allpatientdata=pd.merge(df_train_op,df_train_ip,
                              left_on=['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
       'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
       'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
       'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
       'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
       'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
       'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
       'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
       'ClmAdmitDiagnosisCode'],
                              right_on=['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
       'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
       'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
       'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
       'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
       'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
       'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
       'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
       'ClmAdmitDiagnosisCode']
                              ,how='outer')

# %%
Train_Allpatientdata
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1        BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2        BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3        BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4        BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
# ...            ...        ...          ...         ...       ...
# 558206  BENE159167   CLM69886   2009-09-28  2009-10-02  PRV53671
# 558207  BENE159175   CLM74504   2009-11-03  2009-11-06  PRV54981
# 558208  BENE159177   CLM76485   2009-11-18  2009-11-22  PRV56588
# 558209  BENE159177   CLM79949   2009-12-17  2009-12-18  PRV56575
# 558210  BENE159188   CLM69948   2009-09-28  2009-10-06  PRV54765
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                           30          PHY326117                NaN
# 1                           80          PHY362868                NaN
# 2                           10          PHY328821                NaN
# 3                           40          PHY334319                NaN
# 4                          200          PHY403831                NaN
# ...                        ...                ...                ...
# 558206                    7000          PHY345332          PHY319565
# 558207                    4000          PHY342806          PHY365497
# 558208                    3000          PHY423220          PHY332752
# 558209                    5000          PHY353156                NaN
# 558210                   15000          PHY431177          PHY352941
#
#        OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                 NaN              78943              V5866
# 1                 NaN               6115                NaN
# 2                 NaN               2723                NaN
# 3                 NaN              71988                NaN
# 4                 NaN              82382              30000
# ...               ...                ...                ...
# 558206            NaN               2851               2762
# 558207            NaN              42823               4148
# 558208            NaN               4280               3963
# 558209            NaN               7802               5859
# 558210            NaN               1540              27800
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 0                   V1272                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                   72887               4280               7197
# ...                   ...                ...                ...
# 558206              53550              V0254              V1005
# 558207               4019               3970               4241
# 558208               5859               4019              40390
# 558209                496               2809              V1254
# 558210               6146               2449              42830
#
#        ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 0                     NaN                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                   V4577                NaN                NaN
# ...                   ...                ...                ...
# 558206               5173              79092              70704
# 558207              V1042              49122               4254
# 558208               4111              71534              71590
# 558209              42822               4263               0414
# 558210                412               4019               2800
#
#        ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 0                     NaN                 NaN                 NaN
# 1                     NaN                 NaN                 NaN
# 2                     NaN                 NaN                 NaN
# 3                     NaN                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 558206               2869                4148              9904.0
# 558207               5990                 NaN              8605.0
# 558208              V4502                 NaN              9390.0
# 558209              41400                 NaN                 NaN
# 558210              27801                 NaN              1733.0
#
#         ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6  DeductibleAmtPaid  \
# 0                      NaN                 NaN                0.0
# 1                      NaN                 NaN                0.0
# 2                      NaN                 NaN                0.0
# 3                      NaN                 NaN                0.0
# 4                      NaN                 NaN                0.0
# ...                    ...                 ...                ...
# 558206                 NaN                 NaN             1068.0
# 558207                 NaN                 NaN             1068.0
# 558208                 NaN                 NaN             1068.0
# 558209                 NaN                 NaN             1068.0
# 558210                 NaN                 NaN             1068.0
#
#        ClmAdmitDiagnosisCode AdmissionDt DischargeDt DiagnosisGroupCode
# 0                      56409         NaN         NaN                NaN
# 1                      79380         NaN         NaN                NaN
# 2                        NaN         NaN         NaN                NaN
# 3                        NaN         NaN         NaN                NaN
# 4                      71947         NaN         NaN                NaN
# ...                      ...         ...         ...                ...
# 558206                  2859  2009-09-28  2009-10-02                812
# 558207                 79902  2009-11-03  2009-11-06                228
# 558208                 78605  2009-11-18  2009-11-22                302
# 558209                  7802  2009-12-17  2009-12-18                309
# 558210                  1536  2009-09-28  2009-10-06                340
#
# [558211 rows x 30 columns]

# %%
print(f'Shape of data: {df_test_ben.shape[0]} row and {df_test_ben.shape[1]} columns')
df_test_ben.head()

# %%
print(f'Shape of data: {df_test_inp.shape[0]} row and {df_test_inp.shape[1]} columns')
df_test_inp.head()

# %%
print(f'Shape of data: {df_test_out.shape[0]} row and {df_test_out.shape[1]} columns')
df_test_out.head()

# %%
df_test_out.Provider.nunique()
